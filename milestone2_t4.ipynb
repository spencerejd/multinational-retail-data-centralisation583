# %% [markdown]
# ## Milestone 2 Task 4

# %%
import pandas as pd
from database_utils import DatabaseConnector
from data_extraction import DataExtractor
from data_cleaning import DataCleaning

# %%
# Create an instance of the DataExtractor class
data_extractor = DataExtractor()

# Set file path of pdf
pdf_path = "/Users/spencer/Documents/AiCore/Courses/Projects/retail_data/card_details.pdf"
# Convert pdf into DataFrame
pdf_df = data_extractor.retrieve_pdf_data(pdf_path)
# Out:
# CodeCache: size=131072Kb used=6343Kb max_used=6343Kb free=124729Kb
#  bounds [0x00000001744bc000, 0x0000000174afc000, 0x000000017c4bc000]
#  total_blobs=2248 nmethods=1766 adapters=397
#  compilation: disabled (not enough contiguous free space left)
# Java HotSpot(TM) 64-Bit Server VM warning: CodeCache is full. Compiler has been disabled.
# Java HotSpot(TM) 64-Bit Server VM warning: Try increasing the code cache size using -XX:ReservedCodeCacheSize=
# Returning DataFrame from the given pdf

# %%
# Create an instance of the DataCleaning class, passing DataFrame as an argument
data_cleaner = DataCleaning(pdf_df)
# Clean the DataFrame
clean_pdf_df = data_cleaner.clean_card_data()
clean_pdf_df.head()
clean_pdf_df.info()
# Out:
# DataFrame cleaning operation initiated.
# DataFrame cleaning operation completed.
# <class 'pandas.core.frame.DataFrame'>
# Index: 2449 entries, 110 to 14904
# Data columns (total 4 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   card_number             2449 non-null   object
#  1   expiry_date             2449 non-null   object
#  2   card_provider           2449 non-null   string
#  3   date_payment_confirmed  2449 non-null   object
# dtypes: object(3), string(1)
# memory usage: 95.7+ KB

# %%
# Now let's initialise the engine that we will upload our DataFrame to

# Create an instance of the DatabaseConnector class
database = DatabaseConnector()

# We will set the 'yaml_file_path' to ensure the connection is made to the upload database engine
upload_engine = database.init_db_engine(yaml_file_path='rds_upload_db_creds.yaml')

# Upload 'cleaned_df' to our initialised engine
database.upload_to_db(clean_pdf_df, table_name='dim_card_details')
# Out:
# Called 'init_db_engine' method for database engine initialisation.
# Read credentials from rds_upload_db_creds.yaml
# Database credentials now stored in 'credentials' variable.
# Database engine initialised successfully with the credentials in rds_upload_db_creds.yaml.
# Data uploaded to the 'dim_card_details' table successfully.

# %%
unique_dates = clean_pdf_df['date_payment_confirmed'].unique()
unique_dates_sorted = sorted(unique_dates)
print(unique_dates_sorted)
# Out:
# [datetime.date(1992, 11, 26), datetime.date(1992, 12, 1), datetime.date(1992, 12, 15), datetime.date(1992, 12, 16), datetime.date(1992, 12, 22), datetime.date(1993, 1, 7), datetime.date(1993, 1, 16), datetime.date(1993, 1, 20), datetime.date(1993, 1, 21), datetime.date(1993, 1, 24), datetime.date(1993, 1, 26), datetime.date(1993, 1, 29), datetime.date(1993, 2, 5), datetime.date(1993, 2, 11), datetime.date(1993, 2, 17), datetime.date(1993, 3, 4), datetime.date(1993, 3, 21), datetime.date(1993, 3, 22), datetime.date(1993, 3, 28), datetime.date(1993, 4, 12), datetime.date(1993, 4, 16), datetime.date(1993, 4, 27), datetime.date(1993, 4, 30), datetime.date(1993, 5, 3), datetime.date(1993, 5, 6), datetime.date(1993, 5, 11), datetime.date(1993, 5, 15), datetime.date(1993, 5, 16), datetime.date(1993, 5, 17), datetime.date(1993, 5, 24), datetime.date(1993, 5, 25), datetime.date(1993, 6, 1), datetime.date(1993, 6, 5), datetime.date(1993, 6, 11), datetime.date(1993, 6, 16), datetime.date(1993, 6, 21), datetime.date(1993, 7, 14), datetime.date(1993, 7, 16), datetime.date(1993, 7, 17), datetime.date(1993, 7, 21), datetime.date(1993, 7, 27), datetime.date(1993, 8, 6), datetime.date(1993, 8, 7), datetime.date(1993, 8, 13), datetime.date(1993, 8, 18), datetime.date(1993, 8, 23), datetime.date(1993, 8, 26), datetime.date(1993, 8, 28), datetime.date(1993, 9, 10), datetime.date(1993, 9, 13), datetime.date(1993, 9, 19), datetime.date(1993, 9, 21), datetime.date(1993, 9, 25), datetime.date(1993, 9, 27), datetime.date(1993, 10, 2), datetime.date(1993, 10, 3), datetime.date(1993, 10, 11), datetime.date(1993, 10, 14), datetime.date(1993, 10, 19), datetime.date(1993, 10, 20), datetime.date(1993, 10, 24), datetime.date(1993, 10, 29), datetime.date(1993, 11, 2), datetime.date(1993, 11, 4), datetime.date(1993, 11, 6), datetime.date(1993, 11, 8), datetime.date(1993, 11, 10), datetime.date(1993, 11, 17), datetime.date(1993, 11, 20), datetime.date(1993, 11, 23), datetime.date(1993, 11, 28), datetime.date(1993, 12, 1), datetime.date(1993, 12, 6), datetime.date(1993, 12, 8), datetime.date(1993, 12, 10), datetime.date(1993, 12, 12), datetime.date(1993, 12, 15), datetime.date(1993, 12, 20), datetime.date(1993, 12, 23), datetime.date(1993, 12, 25), datetime.date(1993, 12, 26), datetime.date(1994, 1, 7), datetime.date(1994, 1, 18), datetime.date(1994, 1, 26), datetime.date(1994, 2, 10), datetime.date(1994, 2, 19), datetime.date(1994, 2, 28), datetime.date(1994, 3, 7), datetime.date(1994, 3, 23), datetime.date(1994, 3, 27), datetime.date(1994, 3, 29), datetime.date(1994, 4, 2), datetime.date(1994, 4, 6), datetime.date(1994, 4, 10), datetime.date(1994, 4, 17), datetime.date(1994, 4, 21), datetime.date(1994, 4, 28), datetime.date(1994, 4, 30), datetime.date(1994, 5, 6), datetime.date(1994, 5, 11), datetime.date(1994, 6, 2), datetime.date(1994, 6, 4), datetime.date(1994, 6, 6), datetime.date(1994, 6, 13), datetime.date(1994, 6, 14), datetime.date(1994, 6, 15), datetime.date(1994, 6, 18), datetime.date(1994, 6, 19), datetime.date(1994, 6, 20), datetime.date(1994, 6, 24), datetime.date(1994, 6, 25), datetime.date(1994, 6, 30), datetime.date(1994, 7, 1), datetime.date(1994, 7, 8), datetime.date(1994, 7, 16), datetime.date(1994, 7, 17), datetime.date(1994, 7, 23), datetime.date(1994, 7, 27), datetime.date(1994, 7, 30), datetime.date(1994, 7, 31), datetime.date(1994, 8, 2), datetime.date(1994, 8, 15), datetime.date(1994, 8, 20), datetime.date(1994, 8, 21), datetime.date(1994, 8, 30), datetime.date(1994, 9, 3), datetime.date(1994, 9, 8), datetime.date(1994, 9, 9), datetime.date(1994, 9, 13), datetime.date(1994, 9, 18), datetime.date(1994, 9, 19), datetime.date(1994, 9, 22), datetime.date(1994, 9, 28), datetime.date(1994, 10, 1), datetime.date(1994, 10, 2), datetime.date(1994, 10, 6), datetime.date(1994, 10, 14), datetime.date(1994, 10, 19), datetime.date(1994, 10, 21), datetime.date(1994, 10, 23), datetime.date(1994, 10, 24), datetime.date(1994, 10, 27), datetime.date(1994 ...
